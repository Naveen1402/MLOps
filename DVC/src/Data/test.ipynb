# %%
import pandas as pd

# %%
df = pd.read_csv("twitter_training.csv_test.csv")

# %%
df.head()
# Out:
#      ID  Sentiments                                            Content
# 0  1616         1.0  Time to get used to Black Ops controls again c...
# 1  2660         1.0                   Yooooo this could be so bad ass!
# 2  2335         1.0  This skin for Revenant looks dope!! greasygame...
# 3  9472         2.0  my mercy @AmbarKOrtiz was SO mad at me for mak...
# 4  4207         2.0  RANKED | OVER 3K HOURS IN CSGO twitch.tv/swish...
